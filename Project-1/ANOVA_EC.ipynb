# %%
import pandas as pd 
import numpy as np 
import os

# %%
print(os.listdir())
# Out:
# ['GA-master.py', '.DS_Store', 'ANOVA_EC.ipynb', 'Mu+Mu.csv', 'dataset.txt', 'ElitistGen-GA.csv', 'README.md', 'Mu+1.csv', 'GA-master_backup.py', '.gitignore', 'SteadyGen-GA_version_Armin.csv', '.ipynb_checkpoints', '.git', 'simpleExploratoryAttacker.py', 'steady_stateGA.py', 'SteadyState.csv', 'ElitistGen-GA_Result-Entries.xlsx', '.idea']

# %%
dataframe = ['ElitistGen-GA.csv', 'SteadyGen-GA_version_Armin.csv', 'Mu+1.csv']
df= pd.read_csv('Mu+Mu.csv', sep=",")
for i in dataframe:
    temp = pd.read_csv(i, sep=",")
    temp= temp.loc[temp.]
    df = pd.concat([df, temp], axis=1)
# Out:
#     Unnamed: 0  Run  SPX_best  SPX_Function_Evaluations  Midx_best  \
# 0            0    0  0.997541                        66   0.997544
# 1            1    1  0.997544                       115   0.997541
# 2            2    2  0.997541                        97   0.997544
# 3            3    3  0.997544                        72   0.997544
# 4            4    4  0.997544                        78   0.997543
# 5            5    5  0.997543                       172   0.997542
# 6            6    6  0.997543                        79   0.997543
# 7            7    7  0.997544                        88   0.997544
# 8            8    8  0.997544                        98   0.997544
# 9            9    9  0.997540                        48   0.997543
# 10          10   10  0.997543                        74   0.997543
# 11          11   11  0.997544                        89   0.997544
# 12          12   12  0.997541                       224   0.997542
# ...
